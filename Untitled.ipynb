# %% [markdown]
# ## Importation des librairies

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importation du dataset

# %%
top_twitch = pd.read_csv('twitchdata-update.csv')
top_twitch.shape
# Out:
# (1000, 11)

# %% [markdown]
# ## Visualisation du dataset et du type de données contenue dans celui-ci

# %%
top_twitch
# Out:
#               Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0               xQcOW           6196161750                215250
# 1            summit1g           6091677300                211845
# 2              Gaules           5644590915                515280
# 3            ESL_CSGO           3970318140                517740
# 4                Tfue           3671000070                123660
# ..                ...                  ...                   ...
# 995         LITkillah            122524635                 13560
# 996  빅헤드 (bighead033)            122523705                153000
# 997    마스카 (newmasca)            122452320                217410
# 998     AndyMilonakis            122311065                104745
# 999              Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
top_twitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Channel               1000 non-null   object
#  1   Watch time(Minutes)   1000 non-null   int64
#  2   Stream time(minutes)  1000 non-null   int64
#  3   Peak viewers          1000 non-null   int64
#  4   Average viewers       1000 non-null   int64
#  5   Followers             1000 non-null   int64
#  6   Followers gained      1000 non-null   int64
#  7   Views gained          1000 non-null   int64
#  8   Partnered             1000 non-null   bool
#  9   Mature                1000 non-null   bool
#  10  Language              1000 non-null   object
# dtypes: bool(2), int64(7), object(2)
# memory usage: 72.4+ KB

# %% [markdown]
# ## Vérification de l'existance des données manquantes dans le dataset

# %%
top_twitch.isnull().any()
# Out:
# Channel                 False
# Watch time(Minutes)     False
# Stream time(minutes)    False
# Peak viewers            False
# Average viewers         False
# Followers               False
# Followers gained        False
# Views gained            False
# Partnered               False
# Mature                  False
# Language                False
# dtype: bool

# %% [markdown]
# ## Statisques basique sur notre dataset

# %%
top_twitch.describe()
# Out:
#        Watch time(Minutes)  Stream time(minutes)   Peak viewers  \
# count         1.000000e+03           1000.000000    1000.000000
# mean          4.184279e+08         120515.160000   37065.051000
# std           5.496355e+08          85376.201364   60314.307686
# min           1.221928e+08           3465.000000     496.000000
# 25%           1.631899e+08          73758.750000    9113.750000
# 50%           2.349908e+08         108240.000000   16676.000000
# 75%           4.337399e+08         141843.750000   37569.750000
# max           6.196162e+09         521445.000000  639375.000000
#
#        Average viewers     Followers  Followers gained  Views gained
# count      1000.000000  1.000000e+03      1.000000e+03  1.000000e+03
# mean       4781.040000  5.700541e+05      2.055185e+05  1.166817e+07
# std        8453.684965  8.044134e+05      3.399137e+05  2.490572e+07
# min         235.000000  3.660000e+03     -1.577200e+04  1.757880e+05
# ...

# %%
sns.boxplot(x='Watch time(Minutes)', data=top_twitch)
# Out:
# <AxesSubplot:xlabel='Watch time(Minutes)'>

# %%
sns.pairplot(top_twitch, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %%
top_twitch.groupby('Language').mean()
# Out:
#             Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# Language
# Arabic             2.390504e+08          49935.000000  58281.400000
# Chinese            3.389560e+08         150564.000000  13104.366667
# Czech              2.870943e+08         140782.500000   9918.500000
# English            4.719196e+08         124482.340206  41639.719588
# Finnish            2.157269e+08         209625.000000   9676.000000
# French             3.780744e+08         131811.590909  33865.409091
# German             3.939610e+08         116363.265306  31274.734694
# Greek              2.305530e+08         123345.000000   6289.000000
# Hungarian          2.322294e+08         111825.000000  24780.000000
# Italian            2.520991e+08         123131.470588  17425.117647
# Japanese           4.186577e+08         143068.500000  22013.500000
# Korean             3.609664e+08         119885.259740  18633.038961
# Other              2.988282e+08         232620.000000  11533.000000
# ...

# %%
top_twitch.groupby('Mature').mean()
# Out:
#         Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# Mature
# False          4.313976e+08          118417.50000  39791.463636
# True           3.750076e+08          127537.76087  27937.495652
#
#         Average viewers      Followers  Followers gained  Views gained  \
# Mature
# False       5158.084416  608951.937662     222787.207792  1.286703e+07
# True        3518.760870  439830.765217     147706.017391  7.654563e+06
#
#         Partnered
# Mature
# False    0.977922
# True     0.978261

# %%
top_twitch.groupby('Partnered').mean()
# Out:
#            Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# Partnered
# False             2.782956e+08         124539.545455  25765.727273
# True              4.215802e+08         120424.631902  37319.228016
#
#            Average viewers      Followers  Followers gained  Views gained  \
# Partnered
# False          5287.090909  331942.681818     143304.181818  1.752922e+07
# True           4769.656442  575410.356851     206918.038855  1.153632e+07
#
#              Mature
# Partnered
# False      0.227273
# True       0.230061

# %%
top_twitch[top_twitch['Channel'] == 'FantaBobShow']
# Out:
#           Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 942  FantaBobShow            128845890                 65565          8248
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 942             1936     348598             86339       3598696       True
#
#      Mature Language
# 942    True   French
